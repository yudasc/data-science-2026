# %% [markdown]
# Nama: Prieyuda Akadita S
# NIM: 240401010353
# Kelas: IF403

# %%
# Install library yang dibutuhkan jika running di local.
# jika cell ini gagal jalan, mohon install manual
# !python -m pip install -q pandas numpy


import pandas as pd
import numpy as np

# Muat Dataset Titanic
# Saya menggunakan link ini karena link di modul sepertinya sudah tidak aktif
URL = "https://raw.githubusercontent.com/datasciencedojo/datasets/refs/heads/master/titanic.csv"
df = pd.read_csv(URL)

# Eksplorasi Awal
print(df.shape, df.columns.tolist())
print(df.isnull().sum())

# Filtering — Penumpang Wanita Kelas 1
wk1 = df[(df['Sex']=='female') & (df['Pclass']==1)]
print(wk1['Survived'].mean(), wk1['Age'].mean())

# Groupby — Tingkat Keselamatan per Kelas
hasil = df.groupby('Pclass').agg(
  total=('PassengerId','count'),
  selamat=('Survived','mean'),
  ).round(3)
print(hasil)
# Out:
#   WARNING: The scripts f2py.exe and numpy-config.exe are installed in 'c:\Users\Prieyuda Akadita S\AppData\Local\Python\pythoncore-3.14-64\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# (891, 12) ['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64
# 0.9680851063829787 34.61176470588235
#         total  selamat
# Pclass
# 1         216    0.630
# 2         184    0.473
# 3         491    0.242

# %% [markdown]
# Pengenalan library numpy, struktur data (cara ambil data dan restruktur data) dan cara load data
