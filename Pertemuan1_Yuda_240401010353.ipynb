# %% [markdown]
# Nama: Prieyuda Akadita S
# NIM: 240401010353
# Kelas: IF403

# %%
# SEL 1: Output sederhana
print("Hello, Data Science!")

# SEL 2: Variabel & tipe data
nama = "yuda"
angkatan = 2024
print(f"Halo, {nama} angkatans {angkatan}!")

# SEL 3: List & perulangan
tools = ["Python","Colab","Jupyter","GitHub"]
for i, tool in enumerate(tools, 1):
  print(f" {i}. {tool}")

# SEL 4: Fungsi Python
def perkenalan(nama, prodi, angkatan):
  return f"{nama} | {prodi} | {angkatan}"


print(perkenalan("yuda","Informatika",2024))
# Out:
# Hello, Data Science!
# Halo, yuda angkatans 2024!
#  1. Python
#  2. Colab
#  3. Jupyter
#  4. GitHub
# yuda | Informatika | 2024

# %% [markdown]
# Ini pengenalan pertama untuk python, jupyter notebook dan data science.
